# %% [markdown]
# # CUDA Spectrogram: Drew Schlesener and Denton Jarvis

# %% [markdown]
# ## Environment Setup
# These cells demonstrate how to create and activate the conda environment, install required packages, and prepare CUDA.
# Run these commands in a terminal, not inside Jupyter.

# %%
# !module load cuda anaconda3
# !conda config --set solver libmamba
# !conda env create -f env.yml
# !conda activate spectrogram-cuda
# !conda install ipykernel
# !python -m ipykernel install --user --name spectrogram-cuda --display-name "Python (spectrogram-cuda)"
print("All steps executed, now select generated kernel as notebook kernel and proceed")
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# Downloading and Extracting Packages
# libcblas-3.9.0       | 17 KB     |                                       |   0%
# cuda-cudart-static_l | 1.1 MB    |                                       |   0%
#
# libcusparse-12.5.10. | 199.2 MB  |                                       |   0%
#
#
# libcublas-12.9.1.4   | 446.1 MB  |                                       |   0%
#
#
#
# click-8.3.1          | 90 KB     |                                       |   0%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  |                                       |   0%
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    |                                       |   0%
#
#
#
#
#
#
# cuda-cudart-dev_linu | 380 KB    |                                       |   0%
#
#
#
#
#
#
#
# cuda-version-12.9    | 21 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# cuda-cudart_linux-64 | 193 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cupy-13.6.0          | 351 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.51.0     | 923 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cccl_linux-64-1 | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 17 KB     | ##################################6   |  94%
#
# libcusparse-12.5.10. | 199.2 MB  |                                       |   0%
#
#
# libcublas-12.9.1.4   | 446.1 MB  |                                       |   0%
#
#
#
# click-8.3.1          | 90 KB     | ######5                               |  18%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  |                                       |   0%
# cuda-cudart-static_l | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | 1                                     |   0%
#
# libcusparse-12.5.10. | 199.2 MB  | 5                                     |   1%
#
#
# libcblas-3.9.0       | 17 KB     | ##################################### | 100%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | 7                                     |   2%
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | ####################7                 |  56%
#
# libcusparse-12.5.10. | 199.2 MB  | #7                                    |   5%
#
#
#
#
#
#
# cuda-cudart-dev_linu | 380 KB    | #5                                    |   4%
#
#
#
# click-8.3.1          | 90 KB     | ##################################### | 100%
#
#
#
# click-8.3.1          | 90 KB     | ##################################### | 100%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | 9                                     |   2%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #4                                    |   4%
# cuda-cudart-static_l | 1.1 MB    | ##################################### | 100%
# cuda-cudart-static_l | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# cuda-version-12.9    | 21 KB     | ############################          |  76%
#
# libcusparse-12.5.10. | 199.2 MB  | ##7                                   |   7%
#
#
#
#
#
#
#
#
# cuda-cudart_linux-64 | 193 KB    | ###                                   |   8%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #7                                    |   5%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   |                                       |   0%
#
#
#
#
#
#
#
# cuda-version-12.9    | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# cuda-version-12.9    | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 17 KB     | ##################################6   |  94%
#
# libcusparse-12.5.10. | 199.2 MB  | ###7                                  |  10%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##5                                   |   7%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   | #####4                                |  15%
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | ##################################### | 100%
#
# libcusparse-12.5.10. | 199.2 MB  | ####6                                 |  13%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###1                                  |   9%
#
#
#
#
#
#
#
#
# cuda-cudart_linux-64 | 193 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# cuda-cudart_linux-64 | 193 KB    | ##################################### | 100%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ######4                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | #########2                            |  25%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   | ##########                            |  27%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 17 KB     | ##################################### | 100%
#
# libcusparse-12.5.10. | 199.2 MB  | #####4                                |  15%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | ######################                |  59%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   | ######################9               |  62%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #########4                            |  25%
#
# libcusparse-12.5.10. | 199.2 MB  | ######2                               |  17%
#
#
#
#
#
#
# cuda-cudart-dev_linu | 380 KB    | ##################################### | 100%
#
#
#
#
#
#
# cuda-cudart-dev_linu | 380 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | ##############################        |  81%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   | ############################3         |  77%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ##########6                           |  29%
#
# libcusparse-12.5.10. | 199.2 MB  | ######9                               |  19%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
# cupy-core-13.6.0     | 54.1 MB   | #################################5    |  91%
#
# libcusparse-12.5.10. | 199.2 MB  | #######8                              |  21%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###########9                          |  32%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | ##################################6   |  94%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #############                         |  35%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ######5                               |  18%
#
# libcusparse-12.5.10. | 199.2 MB  | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cupy-13.6.0          | 351 KB    | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.51.0     | 923 KB    | 6                                     |   2%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  |                                       |   0%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | ##################################### | 100%
#
# libcusparse-12.5.10. | 199.2 MB  | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cccl_linux-64-1 | 1.1 MB    | 5                                     |   1%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###############3                      |  41%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   |                                       |   0%
#
# libcusparse-12.5.10. | 199.2 MB  | #########9                            |  27%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ##9                                   |   8%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ###8                                  |  10%
#
# libcusparse-12.5.10. | 199.2 MB  | ##########9                           |  29%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ######7                               |  18%
#
# libcusparse-12.5.10. | 199.2 MB  | ############                          |  33%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #########6                            |  26%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###################4                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.51.0     | 923 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.51.0     | 923 KB    | ##################################### | 100%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##########3                           |  28%
#
# libcusparse-12.5.10. | 199.2 MB  | ############9                         |  35%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | #############6                        |  37%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #######6                              |  21%
#
# libcusparse-12.5.10. | 199.2 MB  | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ################5                     |  45%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ######################                |  59%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###########5                          |  31%
#
# libcusparse-12.5.10. | 199.2 MB  | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ########7                             |  24%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ############1                         |  33%
#
# libcusparse-12.5.10. | 199.2 MB  | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ##########2                           |  28%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #######################1              |  62%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ########################3             |  66%
#
# libcusparse-12.5.10. | 199.2 MB  | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ###########4                          |  31%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #############6                        |  37%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ##############################4       |  82%
#
# libcusparse-12.5.10. | 199.2 MB  | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ############8                         |  35%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##############3                       |  39%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #########################             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ##################################2   |  93%
#
# libcusparse-12.5.10. | 199.2 MB  | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #############9                        |  38%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #########################9            |  70%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###############                       |  41%
#
# libcusparse-12.5.10. | 199.2 MB  | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ###############2                      |  41%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###########################5          |  74%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   |                                       |   0%
#
# libcusparse-12.5.10. | 199.2 MB  | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ################4                     |  44%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | ######4                               |  17%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ############################5         |  77%
#
# libcusparse-12.5.10. | 199.2 MB  | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #################5                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | ##########7                           |  29%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ################9                     |  46%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ##############################1       |  81%
#
# libcusparse-12.5.10. | 199.2 MB  | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ##################6                   |  50%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | #################1                    |  46%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###############################7      |  86%
#
# libcusparse-12.5.10. | 199.2 MB  | #######################5              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ###################8                  |  54%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cupy-13.6.0          | 351 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cupy-13.6.0          | 351 KB    | ##################################### | 100%
#
# libcusparse-12.5.10. | 199.2 MB  | ########################7             |  67%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ####################8                 |  56%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##################8                   |  51%
#
# libcusparse-12.5.10. | 199.2 MB  | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | ##########################5           |  72%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###################4                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | ################################6     |  88%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ##################################1   |  92%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ####################                  |  54%
#
# libcusparse-12.5.10. | 199.2 MB  | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ######################7               |  62%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###################################   |  95%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #######################6              |  64%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #####################5                |  58%
#
# libcusparse-12.5.10. | 199.2 MB  | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ########################3             |  66%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ######################1               |  60%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #########################3            |  69%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ######################8               |  62%
#
# libcusparse-12.5.10. | 199.2 MB  | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ##########################1           |  71%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #######################5              |  64%
#
# libcusparse-12.5.10. | 199.2 MB  | #############################5        |  80%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ##########################9           |  73%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #########################3            |  69%
#
# libcusparse-12.5.10. | 199.2 MB  | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ############################1         |  76%
#
# libcusparse-12.5.10. | 199.2 MB  | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #############################5        |  80%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##########################1           |  71%
#
# libcusparse-12.5.10. | 199.2 MB  | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ###############################2      |  85%
#
# libcusparse-12.5.10. | 199.2 MB  | ###################################4  |  96%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##########################8           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | #################################9    |  92%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | ##################################### | 100%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###########################9          |  75%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ############################8         |  78%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #############################4        |  80%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##############################        |  81%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###############################       |  84%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###############################7      |  86%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ################################4     |  88%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #################################1    |  90%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | #################################9    |  92%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##################################6   |  94%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ##################################### | 100%
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | ##################################### | 100%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ###################################3  |  96%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ####################################4 |  98%
#
# libcusparse-12.5.10. | 199.2 MB  | ##################################### | 100%
#
# libcusparse-12.5.10. | 199.2 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cccl_linux-64-1 | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cccl_linux-64-1 | 1.1 MB    | ##################################### | 100%
#
#
# libcublas-12.9.1.4   | 446.1 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment on Palmetto, use
# #
# #     $ source activate spectrogram-cuda
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# usage: conda [-h] [--no-plugins] [-V] COMMAND ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'build', 'content-trust', 'convert', 'debug', 'develop', 'doctor', 'index', 'inspect', 'metapackage', 'render', 'skeleton', 'env', 'repo', 'verify', 'server', 'token', 'pack')
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Installed kernelspec spectrogram-cuda in /home/schlese/.local/share/jupyter/kernels/spectrogram-cuda
# All steps executed, now select generated kernel as notebook kernel and proceed

# %%
# !pip install cupy-cuda12x
# Out:
# Requirement already satisfied: cupy-cuda12x in /home/schlese/.conda/envs/myenv/lib/python3.12/site-packages (12.3.0)
# Requirement already satisfied: numpy<1.29,>=1.20 in /home/schlese/.conda/envs/myenv/lib/python3.12/site-packages (from cupy-cuda12x) (1.26.4)
# Requirement already satisfied: fastrlock>=0.5 in /home/schlese/.conda/envs/myenv/lib/python3.12/site-packages (from cupy-cuda12x) (0.8.3)

# %% [markdown]
# # Imports
# Load all required Python modules.

# %%
import numpy as np
import cupy as cp
print(cp.cuda.runtime.getDeviceCount())  # Should print 1
print(cp.__version__)
import soundfile as sf
import matplotlib.pyplot as plt
import time

print("Imports successful")
# Out:
# 1
# 13.6.0
# Imports successful

# %% [markdown]
# # Load WAV File

# %%
wav_path = "test.wav" 
signal, sr = sf.read(wav_path)
if signal.ndim > 1:
    signal = np.mean(signal, axis=1)  # make audio file mono for easier processing
print(f"Loaded WAV: {signal.shape}, sample rate={sr}")
# Out:
# Loaded WAV: (374400,), sample rate=44100

# %% [markdown]
# # Move audio buffer to GPU

# %%
# Setting Parameters
win_size = 1024
hop_size = 512
num_frames = (len(signal) - win_size) // hop_size


# Audio framed for CPU / GPU
frames = np.stack([signal[i*hop_size:i*hop_size+win_size] for i in range(num_frames)]) # pack signal into a more compressed array based on hop size and win size
frames = np.hanning(win_size)[None, :] * frames #apply hanning function to remove discontinuities from signal

frames_gpu = cp.asarray(frames, dtype=cp.complex64) #convert frames into a complex64 array
print("Audio copied to GPU")
# Out:
# Audio copied to GPU

# %% [markdown]
# # Compute Spectrogram (CPU)
# GPU FFT could be added later; this version ensures the spectrogram renders.

# %%
start_cpu = time.time()
# Convert to complex (CPU)
frames_cpu = frames.astype(np.complex64)

# Execute FFT on CPU
spec_cpu = np.fft.fft(frames_cpu, axis=1)

# Compute magnitude on CPU
spec = np.abs(spec_cpu)
cpu_time = time.time() - start_cpu
print("Spectrogram computed on CPU")
# Out:
# Spectrogram computed on CPU

# %% [markdown]
# # Plot Spectrogram CPU

# %%
# Calculate time and frequency axes
duration = len(signal) / sr  # total duration in seconds
time_axis = np.linspace(0, duration, num_frames)
freq_axis = np.linspace(0, sr/2, win_size//2)

# Plot with proper axes
plt.figure(figsize=(10, 6))
plt.imshow(20 * np.log10(spec[:, :win_size//2].T + 1e-6), 
           origin="lower", 
           aspect="auto", 
           cmap="viridis",
           extent=[0, duration, 0, sr/2]) 
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Spectrogram (GPU via CuPy)")
plt.colorbar(label="Magnitude (dB)")
plt.tight_layout()
plt.savefig('spectrogram_improved.jpg', dpi=150)
plt.show()

print(f"Audio duration: {duration:.2f} seconds")
print(f"Sample rate: {sr} Hz")
print(f"Frequency resolution: {sr/win_size:.2f} Hz per bin")
print(f"Time resolution: {hop_size/sr*1000:.2f} ms per frame")
# Out:
# Audio duration: 8.49 seconds
# Sample rate: 44100 Hz
# Frequency resolution: 43.07 Hz per bin
# Time resolution: 11.61 ms per frame

# %% [markdown]
# # Compute Spectrogram (GPU)

# %%
start_gpu = time.time()
# Execute FFT on GPU
spec_gpu = cp.fft.fft(frames_gpu, axis=1)

# Compute magnitude on GPU
spec_magnitude = cp.abs(spec_gpu)

spec = cp.asnumpy(spec_magnitude) 
cp.cuda.Stream.null.synchronize()  # Wait for GPU to finish
gpu_time = time.time() - start_gpu
print("Spectrogram computed on GPU")
# Out:
# Spectrogram computed on GPU

# %% [markdown]
# # Plot Spectrogram GPU

# %%
# Calculate time and frequency axes
duration = len(signal) / sr  # total duration in seconds
time_axis = np.linspace(0, duration, num_frames)
freq_axis = np.linspace(0, sr/2, win_size//2)

# Plot with proper axes
plt.figure(figsize=(10, 6))
plt.imshow(20 * np.log10(spec[:, :win_size//2].T + 1e-6), 
           origin="lower", 
           aspect="auto", 
           cmap="magma",
           extent=[0, duration, 0, sr/2]) 
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Spectrogram (GPU via CuPy)")
plt.colorbar(label="Magnitude (dB)")
plt.tight_layout()
plt.savefig('spectrogram_improved.jpg', dpi=150)
plt.show()

print(f"Audio duration: {duration:.2f} seconds")
print(f"Sample rate: {sr} Hz")
print(f"Frequency resolution: {sr/win_size:.2f} Hz per bin")
print(f"Time resolution: {hop_size/sr*1000:.2f} ms per frame")
# Out:
# Audio duration: 8.49 seconds
# Sample rate: 44100 Hz
# Frequency resolution: 43.07 Hz per bin
# Time resolution: 11.61 ms per frame

# %%
print(f"CPU time: {cpu_time:.4f}s")
print(f"GPU time: {gpu_time:.4f}s")
print(f"Speedup: {cpu_time/gpu_time:.2f}x")
# Out:
# CPU time: 0.0123s
# GPU time: 0.0014s
# Speedup: 8.58x
